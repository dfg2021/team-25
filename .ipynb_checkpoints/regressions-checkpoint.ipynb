# %%
# Imports 
# %matplotlib inline

import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

import zipfile

import seaborn as sns
sns.set()
sns.set_context('talk')

import warnings
warnings.filterwarnings('ignore')

import patsy
import statsmodels.api as sm
import scipy.stats as stats
from scipy.stats import ttest_ind, chisquare, normaltest
# Note: the statsmodels import may print out a 'FutureWarning'. Thats fine.

# %%
zf = zipfile.ZipFile('config_files.zip') # having First.csv zipped file.
data = pd.read_csv(zf.open('FFG_Hackathon_Country_Level_Data.csv'))

# %%
data
# Out:
#       Year   Country Name Country Code  AG.LND.AGRI.K2  AG.LND.TOTL.K2  \
# 0     2007        Albania          ALB        11190.00         27400.0
# 1     2007        Algeria          DZA       412520.00       2381740.0
# 2     2007         Angola          AGO       508468.17       1246700.0
# 3     2007      Argentina          ARG      1440330.00       2736690.0
# 4     2007        Armenia          ARM        17519.00         28470.0
# ...    ...            ...          ...             ...             ...
# 1305  2016  Venezuela, RB          VEN       215000.00        882050.0
# 1306  2016        Vietnam          VNM       121722.00        310070.0
# 1307  2016    Yemen, Rep.          YEM       233858.00        527970.0
# 1308  2016         Zambia          ZMB       238360.00        743390.0
# 1309  2016       Zimbabwe          ZWE       162000.00        386850.0
#
#       AG.SRF.TOTL.K2  EG.ELC.COAL.ZS  EG.ELC.FOSL.ZS  EG.ELC.HYRO.ZS  \
# ...

# %%
data.shape
# Out:
# (1310, 38)

# %% [markdown]
# Looking at the dataframe, we notice that in the year 2016, there are no recorded values for a good majority of the columns. Hence, we break up the dataframe into two separate dataframes: pre-2016 and 2016.

# %%
data_till_2016 = data[:-131]
data_till_2016
# Out:
#       Year   Country Name Country Code  AG.LND.AGRI.K2  AG.LND.TOTL.K2  \
# 0     2007        Albania          ALB        11190.00         27400.0
# 1     2007        Algeria          DZA       412520.00       2381740.0
# 2     2007         Angola          AGO       508468.17       1246700.0
# 3     2007      Argentina          ARG      1440330.00       2736690.0
# 4     2007        Armenia          ARM        17519.00         28470.0
# ...    ...            ...          ...             ...             ...
# 1174  2015  Venezuela, RB          VEN       215000.00        882050.0
# 1175  2015        Vietnam          VNM       121478.00        310070.0
# 1176  2015    Yemen, Rep.          YEM       234326.00        527970.0
# 1177  2015         Zambia          ZMB       238360.00        743390.0
# 1178  2015       Zimbabwe          ZWE       162000.00        386850.0
#
#       AG.SRF.TOTL.K2  EG.ELC.COAL.ZS  EG.ELC.FOSL.ZS  EG.ELC.HYRO.ZS  \
# ...

# %%
data_2016 = data[-131:]
data_2016
# Out:
#       Year   Country Name Country Code  AG.LND.AGRI.K2  AG.LND.TOTL.K2  \
# 1179  2016        Albania          ALB         11817.0         27400.0
# 1180  2016        Algeria          DZA        413602.0       2381741.0
# 1181  2016         Angola          AGO        558423.8       1246700.0
# 1182  2016      Argentina          ARG       1487000.0       2736690.0
# 1183  2016        Armenia          ARM         16768.0         28470.0
# ...    ...            ...          ...             ...             ...
# 1305  2016  Venezuela, RB          VEN        215000.0        882050.0
# 1306  2016        Vietnam          VNM        121722.0        310070.0
# 1307  2016    Yemen, Rep.          YEM        233858.0        527970.0
# 1308  2016         Zambia          ZMB        238360.0        743390.0
# 1309  2016       Zimbabwe          ZWE        162000.0        386850.0
#
#       AG.SRF.TOTL.K2  EG.ELC.COAL.ZS  EG.ELC.FOSL.ZS  EG.ELC.HYRO.ZS  \
# ...

# %%
perc_miss = data_till_2016.isnull().sum() * 100 / len(data_till_2016)
missing_values = pd.DataFrame({'column_name': data_till_2016.columns,
                                 'percent_missing': perc_miss})
missing_values
# Out:
#                          column_name  percent_missing
# Year                            Year         0.000000
# Country Name            Country Name         0.000000
# Country Code            Country Code         0.000000
# AG.LND.AGRI.K2        AG.LND.AGRI.K2         0.339271
# AG.LND.TOTL.K2        AG.LND.TOTL.K2         0.339271
# AG.SRF.TOTL.K2        AG.SRF.TOTL.K2         0.339271
# EG.ELC.COAL.ZS        EG.ELC.COAL.ZS         0.000000
# EG.ELC.FOSL.ZS        EG.ELC.FOSL.ZS         0.000000
# EG.ELC.HYRO.ZS        EG.ELC.HYRO.ZS         0.000000
# EG.ELC.NGAS.ZS        EG.ELC.NGAS.ZS         0.000000
# EG.ELC.NUCL.ZS        EG.ELC.NUCL.ZS         8.227311
# EG.ELC.PETR.ZS        EG.ELC.PETR.ZS         0.000000
# EG.ELC.RNEW.ZS        EG.ELC.RNEW.ZS         0.000000
# EG.ELC.RNWX.KH        EG.ELC.RNWX.KH         0.000000
# EG.ELC.RNWX.ZS        EG.ELC.RNWX.ZS         0.000000
# EG.FEC.RNEW.ZS        EG.FEC.RNEW.ZS         0.000000
# ...

# %%
perc_miss_2016 = data_2016.isnull().sum() * 100 / len(data_2016)
missing_values_2016 = pd.DataFrame({'column_name': data_till_2016.columns,
                                 'percent_missing': perc_miss_2016})
missing_values_2016
# Out:
#                          column_name  percent_missing
# Year                            Year         0.000000
# Country Name            Country Name         0.000000
# Country Code            Country Code         0.000000
# AG.LND.AGRI.K2        AG.LND.AGRI.K2         0.000000
# AG.LND.TOTL.K2        AG.LND.TOTL.K2         0.000000
# AG.SRF.TOTL.K2        AG.SRF.TOTL.K2         0.000000
# EG.ELC.COAL.ZS        EG.ELC.COAL.ZS        99.236641
# EG.ELC.FOSL.ZS        EG.ELC.FOSL.ZS       100.000000
# EG.ELC.HYRO.ZS        EG.ELC.HYRO.ZS        99.236641
# EG.ELC.NGAS.ZS        EG.ELC.NGAS.ZS        99.236641
# EG.ELC.NUCL.ZS        EG.ELC.NUCL.ZS       100.000000
# EG.ELC.PETR.ZS        EG.ELC.PETR.ZS        99.236641
# EG.ELC.RNEW.ZS        EG.ELC.RNEW.ZS        99.236641
# EG.ELC.RNWX.KH        EG.ELC.RNWX.KH       100.000000
# EG.ELC.RNWX.ZS        EG.ELC.RNWX.ZS        99.236641
# EG.FEC.RNEW.ZS        EG.FEC.RNEW.ZS       100.000000
# ...

# %% [markdown]
# Now that we know the percentage of missing values in the 2016 columns, we can safely drop columns with a high percentage missing.

# %%
thresh = len(data_till_2016) * .75
data_till_2016.dropna(thresh = thresh, axis = 1, inplace = True)

thresh_2016 = len(data_2016) * .9
data_2016.dropna(thresh = thresh_2016, axis = 1, inplace = True)

# %%
data_till_2016
# Out:
#       Year   Country Name Country Code  AG.LND.AGRI.K2  AG.LND.TOTL.K2  \
# 0     2007        Albania          ALB        11190.00         27400.0
# 1     2007        Algeria          DZA       412520.00       2381740.0
# 2     2007         Angola          AGO       508468.17       1246700.0
# 3     2007      Argentina          ARG      1440330.00       2736690.0
# 4     2007        Armenia          ARM        17519.00         28470.0
# ...    ...            ...          ...             ...             ...
# 1174  2015  Venezuela, RB          VEN       215000.00        882050.0
# 1175  2015        Vietnam          VNM       121478.00        310070.0
# 1176  2015    Yemen, Rep.          YEM       234326.00        527970.0
# 1177  2015         Zambia          ZMB       238360.00        743390.0
# 1178  2015       Zimbabwe          ZWE       162000.00        386850.0
#
#       AG.SRF.TOTL.K2  EG.ELC.COAL.ZS  EG.ELC.FOSL.ZS  EG.ELC.HYRO.ZS  \
# ...

# %%
data_2016
# Out:
#       Year   Country Name Country Code  AG.LND.AGRI.K2  AG.LND.TOTL.K2  \
# 1179  2016        Albania          ALB         11817.0         27400.0
# 1180  2016        Algeria          DZA        413602.0       2381741.0
# 1181  2016         Angola          AGO        558423.8       1246700.0
# 1182  2016      Argentina          ARG       1487000.0       2736690.0
# 1183  2016        Armenia          ARM         16768.0         28470.0
# ...    ...            ...          ...             ...             ...
# 1305  2016  Venezuela, RB          VEN        215000.0        882050.0
# 1306  2016        Vietnam          VNM        121722.0        310070.0
# 1307  2016    Yemen, Rep.          YEM        233858.0        527970.0
# 1308  2016         Zambia          ZMB        238360.0        743390.0
# 1309  2016       Zimbabwe          ZWE        162000.0        386850.0
#
#       AG.SRF.TOTL.K2  EN.ATM.CO2E.GF.KT  EN.ATM.CO2E.GF.ZS  EN.ATM.CO2E.KT  \
# ...

# %%
cols = list(data_2016.columns)
cols.remove("Year")
cols.remove("Country Code")
cols.remove("Country Name")
agg_till_2016 = data_till_2016.groupby("Country Name").agg({i: "sum" for i in cols})
agg_till_2016
# Out:
#                AG.LND.AGRI.K2  AG.LND.TOTL.K2  AG.SRF.TOTL.K2  \
# Country Name
# Albania             106407.90        246600.0        258750.0
# Algeria            3724202.25      21435661.0      21435661.0
# Angola             4776035.64      11220300.0      11220300.0
# Argentina         13237010.00      24630210.0      25023600.0
# Armenia             154035.00        256230.0        267660.0
# ...                       ...             ...             ...
# Venezuela, RB      1936590.00       7938450.0       8208450.0
# Vietnam             967917.00       2790630.0       2979628.0
# Yemen, Rep.        2115112.00       4751730.0       4751730.0
# Zambia             2119730.00       6690510.0       6773490.0
# Zimbabwe           1463500.00       3481650.0       3516840.0
#
#                EN.ATM.CO2E.GF.KT  EN.ATM.CO2E.GF.ZS  EN.ATM.CO2E.KT  \
# Country Name
# Albania                  304.361           6.398837       42463.860
# ...

# %%
new_cols = list(data_2016.columns)
new_cols.remove("Year")
new_cols.remove("Country Code")
new_cols.remove("Country Name")
agg_2016 = data_2016.groupby("Country Name").agg({i: "sum" for i in new_cols})
agg_2016
# Out:
#                AG.LND.AGRI.K2  AG.LND.TOTL.K2  AG.SRF.TOTL.K2  \
# Country Name
# Albania               11817.0         27400.0         28750.0
# Algeria              413602.0       2381741.0       2381741.0
# Angola               558423.8       1246700.0       1246700.0
# Argentina           1487000.0       2736690.0       2780400.0
# Armenia               16768.0         28470.0         29740.0
# ...                       ...             ...             ...
# Venezuela, RB        215000.0        882050.0        912050.0
# Vietnam              121722.0        310070.0        331230.0
# Yemen, Rep.          233858.0        527970.0        527970.0
# Zambia               238360.0        743390.0        752610.0
# Zimbabwe             162000.0        386850.0        390760.0
#
#                EN.ATM.CO2E.GF.KT  EN.ATM.CO2E.GF.ZS  EN.ATM.CO2E.KT  \
# Country Name
# Albania                  161.348           3.556993        4536.079
# ...

# %%
fig = pd.plotting.scatter_matrix(agg_till_2016, figsize = (36, 36))
#axes = pd.plotting.scatter_matrix(df, alpha=0.2)

for a in fig.flatten():
    a.xaxis.label.set_rotation(90)
    a.yaxis.label.set_rotation(0)
    a.yaxis.label.set_ha('right')

plt.tight_layout()
plt.gcf().subplots_adjust(wspace=0, hspace=0)
plt.show()

# %%
fig = pd.plotting.scatter_matrix(agg_2016, figsize = (36, 36))
for a in fig.flatten():
    a.xaxis.label.set_rotation(90)
    a.yaxis.label.set_rotation(0)
    a.yaxis.label.set_ha('right')

plt.tight_layout()
plt.gcf().subplots_adjust(wspace=0, hspace=0)
plt.show()

# %%
sns.scatterplot(data = data_till_2016, x = "EN.ATM.CO2E.KT", y = "EG.GDP.PUSE.KO.PP")
# Out:
# <AxesSubplot:xlabel='EN.ATM.CO2E.KT', ylabel='EG.GDP.PUSE.KO.PP'>

# %% [markdown]
# We know have enough data visualizaton/exploration to have a fair idea of how the features in our data are spread out, so we can move on to data analysis, specifically linear regression and t-test. Because our data is split into two major categories (2016 and pre-2016), we actually run the analysis techinques twice.

# %%
data_2016
# Out:
#       Year   Country Name Country Code  AG.LND.AGRI.K2  AG.LND.TOTL.K2  \
# 1179  2016        Albania          ALB         11817.0         27400.0
# 1180  2016        Algeria          DZA        413602.0       2381741.0
# 1181  2016         Angola          AGO        558423.8       1246700.0
# 1182  2016      Argentina          ARG       1487000.0       2736690.0
# 1183  2016        Armenia          ARM         16768.0         28470.0
# ...    ...            ...          ...             ...             ...
# 1305  2016  Venezuela, RB          VEN        215000.0        882050.0
# 1306  2016        Vietnam          VNM        121722.0        310070.0
# 1307  2016    Yemen, Rep.          YEM        233858.0        527970.0
# 1308  2016         Zambia          ZMB        238360.0        743390.0
# 1309  2016       Zimbabwe          ZWE        162000.0        386850.0
#
#       AG.SRF.TOTL.K2  EN.ATM.CO2E.GF.KT  EN.ATM.CO2E.GF.ZS  EN.ATM.CO2E.KT  \
# ...

# %%
data_2016 = data_2016.rename(columns = {"EN.ATM.CO2E.PC": "CO2E_PERCAP", "EN.POP.DNST": "POP_DENS", "SP.URB.TOTL": "URBAN_POP"})
data_till_2016 = data_till_2016.rename(columns = {"EN.ATM.CO2E.PC": "CO2E_PERCAP", "EN.POP.DNST": "POP_DENS", "EG.USE.COMM.FO.ZS": "FOSS_FUEL", "SP.URB.TOTL": "URBAN_POP"})

# %% [markdown]
# # 2016 Regressions:
# 1) CO2 emissions per capita vs Population density
#
# 2) CO2 emissions per capita vs Urban Population
#
# 3) Multivariate Regression (CO2 emissions per capita vs Population density and Urban Population)

# %%
#2016 Dataset
o1_2016, p1_2016 = patsy.dmatrices("CO2E_PERCAP ~ POP_DENS", data_2016)
mod_1 = sm.OLS(o1_2016, p1_2016)
res_1 = mod_1.fit()
print(res_1.summary())
# Out:
#                             OLS Regression Results
# ...
# Dep. Variable:            CO2E_PERCAP   R-squared:                       0.004
# Model:                            OLS   Adj. R-squared:                 -0.004
# Method:                 Least Squares   F-statistic:                    0.5156
# Date:                Thu, 03 Jun 2021   Prob (F-statistic):              0.474
# Time:                        12:43:40   Log-Likelihood:                -419.47
# No. Observations:                 129   AIC:                             842.9
# Df Residuals:                     127   BIC:                             848.7
# Df Model:                           1
# Covariance Type:            nonrobust
# ...
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Intercept      5.2823      0.575      9.191      0.000       4.145       6.420
# ...

# %%
#2016 Dataset
o2_2016, p2_2016 = patsy.dmatrices("CO2E_PERCAP ~ URBAN_POP", data_2016)
mod_2 = sm.OLS(o2_2016, p2_2016)
res_2 = mod_2.fit()
print(res_2.summary())
# Out:
#                             OLS Regression Results
# ...
# Dep. Variable:            CO2E_PERCAP   R-squared:                       0.000
# Model:                            OLS   Adj. R-squared:                 -0.008
# Method:                 Least Squares   F-statistic:                   0.02144
# Date:                Thu, 03 Jun 2021   Prob (F-statistic):              0.884
# Time:                        12:43:40   Log-Likelihood:                -416.62
# No. Observations:                 128   AIC:                             837.2
# Df Residuals:                     126   BIC:                             843.0
# Df Model:                           1
# Covariance Type:            nonrobust
# ...
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Intercept      5.4026      0.591      9.145      0.000       4.233       6.572
# ...

# %%
#2016 Dataset
o_mult_2016, p_mult_2016 = patsy.dmatrices("CO2E_PERCAP ~ POP_DENS + URBAN_POP", data_2016)
mod_mult = sm.OLS(o_mult_2016, p_mult_2016)
res_mult = mod_mult.fit()
print(res_mult.summary())
# Out:
#                             OLS Regression Results
# ...
# Dep. Variable:            CO2E_PERCAP   R-squared:                       0.004
# Model:                            OLS   Adj. R-squared:                 -0.012
# Method:                 Least Squares   F-statistic:                    0.2557
# Date:                Thu, 03 Jun 2021   Prob (F-statistic):              0.775
# Time:                        12:43:40   Log-Likelihood:                -416.37
# No. Observations:                 128   AIC:                             838.7
# Df Residuals:                     125   BIC:                             847.3
# Df Model:                           2
# Covariance Type:            nonrobust
# ...
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Intercept      5.2938      0.612      8.649      0.000       4.082       6.505
# ...

# %% [markdown]
# # 2007-2015 Regressions
# 1) CO2 emissions per capita vs Population density
#
# 2) CO2 emissions per capita vs Urban Population
#
# 3) Multivariate Regression (CO2 emissions per capita vs Population density and Urban Population)

# %%
#2007-2015 Dataset
o1, p1 = patsy.dmatrices("CO2E_PERCAP ~ URBAN_POP", data_till_2016)
m1 = sm.OLS(o1, p1)
r1 = m1.fit()
print(r1.summary())
# Out:
#                             OLS Regression Results
# ...
# Dep. Variable:            CO2E_PERCAP   R-squared:                       0.000
# Model:                            OLS   Adj. R-squared:                 -0.001
# Method:                 Least Squares   F-statistic:                   0.04192
# Date:                Thu, 03 Jun 2021   Prob (F-statistic):              0.838
# Time:                        12:43:40   Log-Likelihood:                -3928.3
# No. Observations:                1173   AIC:                             7861.
# Df Residuals:                    1171   BIC:                             7871.
# Df Model:                           1
# Covariance Type:            nonrobust
# ...
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Intercept      5.7286      0.214     26.810      0.000       5.309       6.148
# ...

# %%
#2007-2015 Dataset
o2, p2 = patsy.dmatrices("CO2E_PERCAP ~ FOSS_FUEL", data_till_2016)
m2 = sm.OLS(o2, p2)
r2 = mod_2.fit()
print(r2.summary())
# Out:
#                             OLS Regression Results
# ...
# Dep. Variable:            CO2E_PERCAP   R-squared:                       0.000
# Model:                            OLS   Adj. R-squared:                 -0.008
# Method:                 Least Squares   F-statistic:                   0.02144
# Date:                Thu, 03 Jun 2021   Prob (F-statistic):              0.884
# Time:                        12:43:40   Log-Likelihood:                -416.62
# No. Observations:                 128   AIC:                             837.2
# Df Residuals:                     126   BIC:                             843.0
# Df Model:                           1
# Covariance Type:            nonrobust
# ...
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Intercept      5.4026      0.591      9.145      0.000       4.233       6.572
# ...

# %%
#2007-2015 Dataset
o3, p3 = patsy.dmatrices("CO2E_PERCAP ~ POP_DENS", data_till_2016)
m3 = sm.OLS(o3, p3)
r3 = m3.fit()
print(r3.summary())
# Out:
#                             OLS Regression Results
# ...
# Dep. Variable:            CO2E_PERCAP   R-squared:                       0.006
# Model:                            OLS   Adj. R-squared:                  0.005
# Method:                 Least Squares   F-statistic:                     6.869
# Date:                Thu, 03 Jun 2021   Prob (F-statistic):            0.00889
# Time:                        12:43:40   Log-Likelihood:                -3925.0
# No. Observations:                1173   AIC:                             7854.
# Df Residuals:                    1171   BIC:                             7864.
# Df Model:                           1
# Covariance Type:            nonrobust
# ...
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Intercept      5.5998      0.208     26.923      0.000       5.192       6.008
# ...

# %%
#2007-2015 Dataset
o_mult, p_mult = patsy.dmatrices("CO2E_PERCAP ~ POP_DENS + URBAN_POP + FOSS_FUEL", data_till_2016)
mod_mult_large = sm.OLS(o_mult, p_mult)
res_mult_large = mod_mult_large.fit()
print(res_mult_large.summary())
# Out:
#                             OLS Regression Results
# ...
# Dep. Variable:            CO2E_PERCAP   R-squared:                       0.228
# Model:                            OLS   Adj. R-squared:                  0.225
# Method:                 Least Squares   F-statistic:                     102.4
# Date:                Thu, 03 Jun 2021   Prob (F-statistic):           4.28e-58
# Time:                        12:43:40   Log-Likelihood:                -3300.1
# No. Observations:                1046   AIC:                             6608.
# Df Residuals:                    1042   BIC:                             6628.
# Df Model:                           3
# Covariance Type:            nonrobust
# ...
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Intercept     -2.0608      0.472     -4.368      0.000      -2.987      -1.135
# ...
